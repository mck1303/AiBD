# %%
import psycopg2 as pg
import pandas as pd

connection = pg.connect(host='pgsql-196447.vipserv.org', port=5432, dbname='wbauer_adb', user='wbauer_adb', password='adb2020')
#city = pd.read_sql('select * from city',con=connection)
#film_category= pd.read_sql('select * from film_category',con=connection)
#category=pd.read_sql('select * from category',con=connection)
#film=pd.read_sql('select * from film',con=connection)
#rental=pd.read_sql('select * from rental',con=connection)
#payment=pd.read_sql('select * from payment',con=connection)
#customer=pd.read_sql('select * from customer',con=connection)
#staff=pd.read_sql('select * from staff',con=connection)
#film_actor=pd.read_sql('select * from film_actor',con=connection)

# %%
#1

film_category= pd.read_sql('select distinct category_id from film_category',con=connection)
print(len(film_category))
# Out:
# 16

# %%
#2
category=pd.read_sql('select name from category order by name asc',con=connection)
category
# Out:
#            name
# 0        Action
# 1     Animation
# 2      Children
# 3      Classics
# 4        Comedy
# 5   Documentary
# 6         Drama
# 7        Family
# 8       Foreign
# 9         Games
# 10       Horror
# 11        Music
# 12          New
# 13       Sci-Fi
# 14       Sports
# 15       Travel

# %%
#3
film=pd.read_sql('select release_year, title from film order by release_year asc',con=connection)
print(film['title'][0],"-najstarszy")
print(film['title'][len(film)-1],"-najmłodszy")
# Out:
# Chamber Italian -najstarszy
# Zorro Ark -najmłodszy

# %%
#4
rental=pd.read_sql("select rental_date from rental where rental_date between '2005-07-01' and '2005-08-01'",con=connection)
print(len(rental))
# Out:
# 6709

# %%
#5
rental2=pd.read_sql("select rental_date from rental where rental_date between '2010-01-01' and '2011-02-01'",con=connection)
print(len(rental2))
# Out:
# 0

# %%
#6
payment=pd.read_sql('select amount from payment order by amount desc FETCH FIRST ROW ONLY',con=connection)
payment
# Out:
#    amount
# 0   11.99

# %%
#7
IDs=pd.read_sql("select country_id, country from country where country ='Poland' OR country ='Nigeria' OR country ='Bangladesh' ",con=connection)

# %%
city_id = pd.read_sql('select country_id, city_id from city where country_id=12 or country_id=69 or country_id=76',con=connection)

# %%
address = pd.read_sql('select city_id, address_id from address where city_id in (69,97,133,141,143,152,217,218,220,234,236,252,255,314,374,381,389,390,409,488,525,549,577,596)',con=connection)

# %%
customer=pd.read_sql('select first_name, last_name, address_id from customer where address_id in (22,25,84,107,132,160,202,236,254,275,282,285,289,291,323,334,337,385,414,506,564,568,577,578)',con=connection)
customer
# Out:
#    first_name  last_name  address_id
# 0       Carol     Garcia          22
# 1    Michelle      Clark          25
# 2     Marilyn       Ross          84
# 3      Gladys   Hamilton         107
# 4    Marjorie     Tucker         132
# 5      Bertha   Ferguson         160
# 6       Elsie     Kelley         202
# 7   Constance       Reid         236
# 8          Jo     Fowler         254
# 9        Leah     Curtis         275
# 10       Olga    Jimenez         282
# 11     Tracey    Barrett         285
# 12      Sonia    Gregory         289
# 13      Velma      Lucas         291
# 14      Brian      Wyman         323
# 15      Frank   Waggoner         334
# 16    Stephen     Qualls         337
# 17    Russell    Brinson         385
# 18     Rodney    Moeller         414
# 19      Ruben      Geary         506
# 20     Jimmie  Eggleston         564
# 21    Wallace      Slone         568
# 22    Johnnie   Chisholm         577
# 23     Sidney   Burleson         578

# %%
#8
staff8=pd.read_sql('select address_id from staff',con=connection)
address8 = pd.read_sql('select address, address_id from address where address_id in (3,4)',con=connection)
address8
# Out:
#                 address  address_id
# 0     23 Workhaven Lane           3
# 1  1411 Lillydale Drive           4

# %%
#9
country9=pd.read_sql("select country_id, country from country where country ='Spain' OR country ='Argentina' ",con=connection)
city_id9 = pd.read_sql('select country_id, city_id from city where country_id=6 or country_id=87 ',con=connection)
address9 = pd.read_sql('select city_id, address_id from address where city_id in (1,20,43,45,128,146,161,165,181,289,334,388,424,454,457,459,524,567)',con=connection)
staff9=pd.read_sql('select address_id from staff where address_id in (28,56,93,111,223,247,298,327,336,364,399,410,450,474,536,555,566,591)',con=connection)
print(len(staff9))
# Out:
# 0

# %%
#10
rental10=pd.read_sql('select distinct inventory_id from rental order by inventory_id asc',con=connection)
print("Wystąpiły wszystkie wartości inventory_id od 1 do 4581 poza 5")
inventory10=pd.read_sql('select distinct film_id from inventory order by film_id asc',con=connection)
print("film o inventory_id=5 ma film_id=1, tak jak w przypadku m.in. inventory_id=4, więc nie trzeba brać tego pod uwagę")

lista10=[]
listanot10=[]
for i in range(958):
    lista10.append(inventory10['film_id'][i])
for i in range(1000):
    if i+1 not in lista10:
        listanot10.append(i+1)

film_category10=pd.read_sql('select distinct category_id, film_id  from film_category where film_id not in (14,33,36,38,41,87,108,128,144,148,171,192,195,198,217,221,318,325,332,359,386,404,419,495,497,607,642,669,671,701,712,713,742,801,802,860,874,909,943,950,954,955)',con=connection)
catlist=[]
for i in range(len(film_category10['category_id'])):
    if film_category10['category_id'][i] not in catlist:
        catlist.append(film_category10['category_id'][i])
category10=pd.read_sql('select name, category_id from category where category_id in (1, 4, 12, 2, 9, 8, 5, 16, 7, 15, 14, 6, 10, 11, 13, 3) order by name asc',con=connection)
category10
# Out:
# Wystąpiły wszystkie wartości inventory_id od 1 do 4581 poza 5
# film o inventory_id=5 ma film_id=1, tak jak w przypadku m.in. inventory_id=4, więc nie trzeba brać tego pod uwagę
#            name  category_id
# 0        Action            1
# 1     Animation            2
# 2      Children            3
# 3      Classics            4
# 4        Comedy            5
# 5   Documentary            6
# 6         Drama            7
# 7        Family            8
# 8       Foreign            9
# 9         Games           10
# 10       Horror           11
# 11        Music           12
# 12          New           13
# 13       Sci-Fi           14
# 14       Sports           15
# 15       Travel           16

# %%
#11
#Rozumiem że "w Ameryce" oznacza w Stanach Zjednoczonych Ameryki Północnej
country11=pd.read_sql("select country_id, country from country where country ='United States'  ",con=connection)
print("id Stanów Zjednoczonych to 103")
city_id11 = pd.read_sql('select country_id, city_id from city where country_id=103',con=connection)
city_list11=[]
for i in range(len(city_id11['city_id'])):
    city_list11.append(city_id11['city_id'][i])
city_list11
address11 = pd.read_sql('select city_id, address_id from address where city_id in (11,33,41,42,65,94,101,120,123,126,135,140,155,171,177,178,185,187,245,262,292,295,306,322,333,404,433,435,441,446,449,499,508,520,573)',con=connection)

address_list11=[]
for i in range(len(address11['address_id'])):
    address_list11.append(address11['address_id'][i])
address_list11
customer11=pd.read_sql('select customer_id, address_id from customer where address_id in (6,10,18,55,66,67,100,116,122,144,150,153,162,185,186,216,218,252,274,280,281,296,299,310,313,335,387,405,425,462,484,509,532,543,567,599)',con=connection)

cus_list11=[]
for i in range(len(customer11['customer_id'])):
    cus_list11.append(customer11['customer_id'][i])
film_category11

catlist11=[]
for i in range(len(film_category11['category_id'])):
    if film_category11['category_id'][i] not in catlist11:
        catlist11.append(film_category11['category_id'][i])
catlist11

category11=pd.read_sql('select name, category_id from category where category_id in (1, 12, 2, 5, 7, 8, 15, 14, 6, 10, 9, 11, 16, 4, 3, 13) order by name asc',con=connection)
category11
# Out:
# id Stanów Zjednoczonych to 103
#            name  category_id
# 0        Action            1
# 1     Animation            2
# 2      Children            3
# 3      Classics            4
# 4        Comedy            5
# 5   Documentary            6
# 6         Drama            7
# 7        Family            8
# 8       Foreign            9
# 9         Games           10
# 10       Horror           11
# 11        Music           12
# 12          New           13
# 13       Sci-Fi           14
# 14       Sports           15
# 15       Travel           16

# %%
#12
actor12=pd.read_sql("select actor_id, first_name, last_name from actor where first_name='Olympia' and last_name='Pfeiffer' or first_name='Julia' and last_name='Zellweger' or first_name='Ellen' and last_name='Presley'",con=connection)
print("Poszukiwane actor_id to: 93, 171, 186")
film_actor12=pd.read_sql('select actor_id, film_id from film_actor where actor_id in (93,171,186)',con=connection)
act_list12=[]
for i in range(len(film_actor12['film_id'])):
    act_list12.append(film_actor12['film_id'][i])
act_list12 
film12=pd.read_sql('select distinct film_id, title from film where film_id in(71,  120,  124,  280,  325,  339,  427,  445,  453,  473,  573,  621,  644,  678,  680,  699,  744,  768,  777,  835,  856,  874,  909,  916,  982,  49,  146,  166,  181,  219,  273,  296,  318,  342,  397,  447,  450,  466,  549,  560,  566,  608,  625,  645,  701,  761,  779,  849,  872,  892,  898,  903,  953,  95,  187,  208,  228,  237,  422,  482,  508,  552,  579,  637,  648,  654,  729,  983,  994  )',con=connection)

f_list12=[]
for i in range(len(film12['title'])):
    f_list12.append(film12['title'][i])
f_list12
# Out:
# Poszukiwane actor_id to: 93, 171, 186
# ['Lambs Cincinatti',
#  'Fugitive Maguire',
#  'Pickup Driving',
#  'Outlaw Hanky',
#  'Chitty Lock',
#  'Wyoming Storm',
#  'Effect Gladiator',
#  'Tadpole Park',
#  'Turn Star',
#  'Floats Garden',
#  'Express Lonely',
#  'Idols Snatchers',
#  'Color Philadelphia',
#  'Treasure Command',
#  'Dares Pluto',
#  'Homeward Cider',
#  'Breakfast Goldfinger',
#  'Maude Mod',
#  'Hanky October',
#  'Minds Truman',
#  'Women Dorado',
#  'Majestic Floats',
#  'Roots Remember',
#  'Mars Roman',
#  'Caribbean Liberty',
#  'Hyde Doctor',
#  'Intolerable Intentions',
#  'Sense Greek',
#  'Streetcar Intentions',
#  'Cranes Reservoir',
#  'Magnolia Forrester',
#  'Panky Submarine',
#  'Empire Malkovich',
#  'Divorce Shining',
#  'Scarface Bang',
#  'Others Soup',
#  'Private Drop',
#  'Hollow Jeopardy',
#  'Tourist Pelican',
#  'Detective Vision',
#  'None Spiking',
#  'Psycho Shrunk',
#  'Badman Dawn',
#  'Ice Crossing',
#  'Wait Cider',
#  'Won Dares',
# ...
